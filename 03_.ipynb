# %% [markdown]
# Take input from users and

# %%
city = input("Enter the Name of Your city")
print("Your city is: ",city)
# Out:
# Your city is:  Bhatpar

# %%
pi="3.14"
pi=float(pi)
si=pi*2
print(f"pi*2 = {si}")
# Out:
# pi*2 = 6.28
