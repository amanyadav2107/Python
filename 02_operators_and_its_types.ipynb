# %% [markdown]
# 1. Set price = 250 and quantity = 3. Print the total cost.
# 2. Use % to check if 91 is even (Even means number % 2 ==0).
# 3. A student passes if marks >= 40 and attendence >= 75. Set values and print True/False.
# 4. Check wheather "Chemistry" is in the subject list and above.

# %%
price = 250
quantity = 3
print(price * quantity)
# Out:
# 750

# %%
num = 9

if num % 2 == 0:
    print(f"{num} is even")
