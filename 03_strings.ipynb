# %% [markdown]
# 1. Store your full name and print ists length.
# 2. Print only the first 3 character of your nameusing a slice.
# 3. Take "hello world" and use strip() then upper().
# 4. Split "one two three four" into a list and print it.

# %%
name="Aman yadav"
print(len(name))
print(name[0:3])
print(name.lower())
print(name.replace("Aman", "Amey"))
string1 = "  hello world    "
print(f" ' {string.strip()}'")
# Out:
# Running cells with 'Python 3.13.14' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Aman Yadav/AppData/Local/Microsoft/WindowsApps/python3.13.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
name="Aman Yadav"
print(f" '{name}")
