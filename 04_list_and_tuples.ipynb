# %%
marks=[78,85,98,90,74]
subject=["Marhs","Physics","Python"]

marks.sort()
subject.sort()
print("after sort : ", marks)
print("after sort : ", subject)
# Out:
# after sort :  [74, 78, 85, 90, 98]
# after sort :  ['Marhs', 'Physics', 'Python']

# %%
location =(26.67,77.45)
print(location)
# Out:
# (26.67, 77.45)

# %% [markdown]
# 1. Make a list of 5 temperature and print the highest .
# 2. Add a 6th temperature with append(). then sort the list.
# 3. Print the averge of a number.
# 4. Create a tuple holding your(roll_number, name) and print it.

# %%
temperature = [ 41,45,32,39,40]
print("max : ", max(temperature))
print("min : ", min(temperature))
temperature[0]=42
print("after append : ", temperature)
print("sum : ", sum(temperature))
print("average : ", (sum(temperature)/len(temperature)))
# Out:
# max :  45
# min :  32
# after append :  [42, 45, 32, 39, 40]
# sum :  198
# average :  39.6

# %%
author={
    "book" : "Python",
    "title" : "list",
    "page" : 200
    }
print("book: ", author["book"])
print("title :", author["title"])
# Out:
# book:  Python
# title : list
