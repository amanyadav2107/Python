# %%
arr = [
    [1,2,3,4],
    [5,6,7,8],
    [10,9,11,12],
    [14,15,16,17]
]
print(arr[1: ])
print(arr[-4:-1])
# Out:
# [[5, 6, 7, 8], [10, 9, 11, 12], [14, 15, 16, 17]]
# [[1, 2, 3, 4], [5, 6, 7, 8], [10, 9, 11, 12]]
