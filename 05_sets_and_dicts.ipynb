# %%
author={
    "book1" :{"name":"Python", "year":10, "topic":"Dictionary"},
    "book2" :{"name":"Maths", "year":11, "topic":"Sets"},
    "book3" :{"name":"Physics", "year":12, "topic":"Gravitation"},

}
print(author["book1"])
print(author["book2"]["name"])
print(author["book2"]["topic"])
print(author.get("book1"))
print(author.get("book3",{}).get("year","Year Not found"))
# Out:
# {'name': 'Python', 'year': 10, 'topic': 'Dictionary'}
# Maths
# Sets
# {'name': 'Python', 'year': 10, 'topic': 'Dictionary'}
# 12
