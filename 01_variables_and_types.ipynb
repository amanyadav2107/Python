# %% [markdown]
# # TRY IT BY YOURSELF
# # 1. Create a variable 'city' holding the name of your city and print it.
# # 2. Create two number variables and print their type using type().
# # 3. Convert the string "3.14" into a float and multiply it by 2.
# # 4. Use an f-string to print: "My city is <city> and I am <age>.

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
city = input("Enter the Name of Your city")
print("Your city is: ",city)
# Out:
# Your city is:  Bhatpar rani

# %%
a = 29
b = 2.43
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>
