# %%
marks = 75
if marks >= 40:
    print("Result : PASS")
# Out:
# Result : PASS

# %%
number = 2
if number >= 0:
    print("Result: POSITIVE")
else :
    print("Result : NEGATIVE")
# Out:
# Result: POSITIVE

# %%
cgpa=float(input("Enter your cgpa:"))
attendance=int(input("Enter Your attendace"))
if cgpa >= 8.5 and attendance >= 85:
    print("Eligible For Scholarship")
# Out:
# Eligible For Scholarship

# %%
for i in range (5):
    print(f"i ={i}")
# Out:
# i =0
# i =1
# i =2
# i =3
# i =4

# %%
print("Even number from 2 to 10:") #for loop for range 
for n in range(2, 11, 2): #initialization and range and updation
    print(n, end=" ") #end=" " keep them on the line
print()
# Out:
# Even number from 2 to 10:
# 2 4 6 8 10

# %% [markdown]
# for loop over a list

# %%
marks =[75, 85, 62, 90, 74]
for mark in marks:
    print(f"Mark:{mark}")
# Out:
# Mark:75
# Mark:85
# Mark:62
# Mark:90
# Mark:74

# %%
#Looping over strings and dictionary
for letter in "PYTHON":
    print(letter, end=" ")
print()

student ={"name": "Aman", "roll": 42, "cgpa":8.7}
for key, value in student.items():
    print(f"{key}->{value}")
# Out:
# P Y T H O N
# name->Aman
# roll->42
# cgpa->8.7
